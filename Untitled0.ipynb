# %% [markdown]
# <a href="https://colab.research.google.com/github/2115425Amar/First-ML-Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
import numpy as np

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
# yellow walon ka placement ho gya, blue walon ka nahi hua

# %%
# logistic regression ml algo

# %% [markdown]
# # Steps
#
# # 0. Preprocess + EDA - Exploratory Data Analysis + Feature Selection
# # 1. Extract input and output cols
# # 2. Scale the values
# # 3. Train test split
# # 4. Train the model
# # 5. Evaluate the model/model selection
# # 6. Deploy the model

# %%
x = df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
train_test_split(x,y,test_size=0.1)
# Out:
# [    cgpa     iq
#  18   4.0  100.0
#  84   5.7  169.0
#  81   5.4  107.0
#  34   4.8  163.0
#  26   7.0  199.0
#  ..   ...    ...
#  23   4.7   87.0
#  76   4.9  155.0
#  10   6.0   45.0
#  19   5.2  132.0
#  74   6.7  154.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  64   7.0   64.0
#  98   6.3  103.0
#  59   4.8  112.0
#  24   4.7  121.0
#  25   5.0   91.0
#  62   6.0  102.0
#  13   6.4  116.0
#  16   5.2  224.0
#  86   5.1  128.0
#  67   5.0  118.0,
#  18    0
#  84    0
#  81    0
#  34    0
#  26    1
#       ..
#  23    0
#  76    0
#  10    1
#  19    0
#  74    1
#  Name: placement, Length: 90, dtype: int64,
#  64    1
#  98    1
#  59    0
#  24    0
#  25    0
#  62    0
#  13    1
#  16    0
#  86    0
#  67    0
#  Name: placement, dtype: int64]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 92   5.2  110.0
# 97   6.7  182.0
# 69   8.5  120.0
# 89   4.9  151.0
# 90   7.3   86.0
# ..   ...    ...
# 52   7.0  175.0
# 54   6.4  141.0
# 15   5.1  176.0
# 76   4.9  155.0
# 61   7.3  137.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 36   5.7  140.0
# 41   5.4  114.0
# 43   6.8  141.0
# 13   6.4  116.0
# 80   4.9  196.0
# 84   5.7  169.0
# 17   3.3  183.0
# 4    5.8  142.0
# 73   4.9   61.0
# 91   7.5  158.0

# %%
y_train
# Out:
# 92    0
# 97    1
# 69    1
# 89    0
# 90    1
#      ..
# 52    1
# 54    1
# 15    0
# 76    0
# 61    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 36    0
# 41    0
# 43    1
# 13    1
# 80    0
# 84    0
# 17    0
# 4     0
# 73    0
# 91    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.73087183, -0.2918191 ],
#        [ 0.58998088,  1.52994175],
#        [ 2.17500413, -0.03879676],
#        [-0.99504238,  0.74557249],
#        [ 1.11832196, -0.89907271],
#        [-0.81892868,  0.16362111],
#        [ 1.82277674,  1.125106  ],
#        [ 0.76609457,  0.41664345],
#        [-0.2905876 ,  0.26483005],
#        [-0.90698553, -1.4810241 ],
#        [-1.17115607, -0.87377048],
#        [-0.99504238, -0.03879676],
#        [-0.02641705, -0.49423697],
#        [ 1.11832196, -1.80995314],
#        [ 0.94220827,  0.74557249],
#        [-1.17115607, -1.75934867],
#        [-1.43532661,  0.69496803],
#        [-1.08309922,  0.49255015],
#        [-1.25921292,  0.61906132],
#        [-0.02641705,  0.69496803],
#        [ 1.20637881,  0.26483005],
#        [ 0.41386718, -0.79786378],
#        [ 0.41386718,  0.9732926 ],
#        [-1.08309922,  1.0491993 ],
#        [-0.20253075,  1.125106  ],
#        [-0.55475814,  0.44194569],
#        [-0.64281499, -0.01349452],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.2905876 ,  0.46724792],
#        [-0.55475814, -0.19061016],
#        [ 0.67803773,  0.49255015],
#        [ 0.32581034, -0.14000569],
#        [-0.99504238,  1.88417302],
#        [-0.2905876 ,  1.20101271],
#        [-2.40395194,  1.55524398],
#        [-0.20253075,  0.51785239],
#        [-0.99504238, -1.53162856],
#        [ 1.29443566,  0.92268813]])

# %% [markdown]
# Model Training

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
print(type(clf))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Prediction

# %%
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 1, 1, 0, 0, 0, 0, 0, 1])

# %%
y_test
# Out:
# 36    0
# 41    0
# 43    1
# 13    1
# 80    0
# 84    0
# 17    0
# 4     0
# 73    0
# 91    1
# Name: placement, dtype: int64

# %%
# Checking Accuracy

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
# Decision Boundary

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl', 'wb'))
